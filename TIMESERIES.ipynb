# %% [markdown]
# <a href="https://colab.research.google.com/github/saiprem-eng/Bitcoin-prediction/blob/master/TIMESERIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv
# Out:
# --2024-08-16 19:21:06--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 178509 (174K) [text/plain]
# Saving to: ‘BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv.2’
#
# BTC_USD_2013-10-01_ 100%[===================>] 174.33K  --.-KB/s    in 0.004s
#
# 2024-08-16 19:21:07 (46.9 MB/s) - ‘BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv.2’ saved [178509/178509]

# %%
import pandas as pd
df=pd.read_csv("/content/BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv")
df
# Out:
#      Currency        Date  Closing Price (USD)  24h Open (USD)  \
# 0         BTC  2013-10-01           123.654990      124.304660
# 1         BTC  2013-10-02           125.455000      123.654990
# 2         BTC  2013-10-03           108.584830      125.455000
# 3         BTC  2013-10-04           118.674660      108.584830
# 4         BTC  2013-10-05           121.338660      118.674660
# ...       ...         ...                  ...             ...
# 2782      BTC  2021-05-14         49764.132082    49596.778891
# 2783      BTC  2021-05-15         50032.693137    49717.354353
# 2784      BTC  2021-05-16         47885.625255    49926.035067
# 2785      BTC  2021-05-17         45604.615754    46805.537852
# 2786      BTC  2021-05-18         43144.471291    46439.336570
#
#       24h High (USD)  24h Low (USD)
# 0         124.751660     122.563490
# 1         125.758500     123.633830
# 2         125.665660      83.328330
# 3         118.675000     107.058160
# ...

# %%
time=df["Date"]
price=df['Closing Price (USD)']

# %%
time
# Out:
# 0       2013-10-01
# 1       2013-10-02
# 2       2013-10-03
# 3       2013-10-04
# 4       2013-10-05
#            ...
# 2782    2021-05-14
# 2783    2021-05-15
# 2784    2021-05-16
# 2785    2021-05-17
# 2786    2021-05-18
# Name: Date, Length: 2787, dtype: object

# %%
time=time.to_numpy()

# %%
price=price.to_numpy()
price
# Out:
# array([  123.65499   ,   125.455     ,   108.58483   , ...,
#        47885.62525472, 45604.61575361, 43144.47129086])

# %%
time=pd.DataFrame(time)
price=pd.DataFrame(price)

# %%
time
# Out:
#                0
# 0     2013-10-01
# 1     2013-10-02
# 2     2013-10-03
# 3     2013-10-04
# 4     2013-10-05
# ...          ...
# 2782  2021-05-14
# 2783  2021-05-15
# 2784  2021-05-16
# 2785  2021-05-17
# 2786  2021-05-18
#
# [2787 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
type(time),type(price)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
price=price.to_numpy()
price
# Out:
# array([[  123.65499   ],
#        [  125.455     ],
#        [  108.58483   ],
#        ...,
#        [47885.62525472],
#        [45604.61575361],
#        [43144.47129086]])

# %%
df
# Out:
#      Currency        Date  Closing Price (USD)  24h Open (USD)  \
# 0         BTC  2013-10-01           123.654990      124.304660
# 1         BTC  2013-10-02           125.455000      123.654990
# 2         BTC  2013-10-03           108.584830      125.455000
# 3         BTC  2013-10-04           118.674660      108.584830
# 4         BTC  2013-10-05           121.338660      118.674660
# ...       ...         ...                  ...             ...
# 2782      BTC  2021-05-14         49764.132082    49596.778891
# 2783      BTC  2021-05-15         50032.693137    49717.354353
# 2784      BTC  2021-05-16         47885.625255    49926.035067
# 2785      BTC  2021-05-17         45604.615754    46805.537852
# 2786      BTC  2021-05-18         43144.471291    46439.336570
#
#       24h High (USD)  24h Low (USD)
# 0         124.751660     122.563490
# 1         125.758500     123.633830
# 2         125.665660      83.328330
# 3         118.675000     107.058160
# ...

# %%
bitcoin=df[["Date","Closing Price (USD)"]]
bitcoin.head()
# Out:
#          Date  Closing Price (USD)
# 0  2013-10-01            123.65499
# 1  2013-10-02            125.45500
# 2  2013-10-03            108.58483
# 3  2013-10-04            118.67466
# 4  2013-10-05            121.33866

# %%
bitcoin.plot()
# Out:
# <Axes: >

# %%
bitcoin
# Out:
#             Date  Closing Price (USD)
# 0     2013-10-01           123.654990
# 1     2013-10-02           125.455000
# 2     2013-10-03           108.584830
# 3     2013-10-04           118.674660
# 4     2013-10-05           121.338660
# ...          ...                  ...
# 2782  2021-05-14         49764.132082
# 2783  2021-05-15         50032.693137
# 2784  2021-05-16         47885.625255
# 2785  2021-05-17         45604.615754
# 2786  2021-05-18         43144.471291
#
# [2787 rows x 2 columns]

# %%
bitcoin[300:]
# Out:
#             Date  Closing Price (USD)
# 300   2014-07-28           580.110000
# 301   2014-07-29           585.448750
# 302   2014-07-30           580.517500
# 303   2014-07-31           564.570000
# 304   2014-08-01           583.390000
# ...          ...                  ...
# 2782  2021-05-14         49764.132082
# 2783  2021-05-15         50032.693137
# 2784  2021-05-16         47885.625255
# 2785  2021-05-17         45604.615754
# 2786  2021-05-18         43144.471291
#
# [2487 rows x 2 columns]

# %%
x_train , x_test  = time[:int((1-0.2) * len(bitcoin) ) ] , price[:int((1-0.2) * len(bitcoin) ) ]
y_train , y_test = time[int((1-0.2) * len(bitcoin) ): ] , price[int((1-0.2) * len(bitcoin) ): ]

# %%
naive_forecast=y_test[:-1]
len(x_test),len(naive_forecast),x_test[-10:],naive_forecast[-10:]
# Out:
# (2229,
#  557,
#  array([[9458.22335963],
#         [9455.72469261],
#         [9225.99547934],
#         [9131.41063031],
#         [9197.63234462],
#         [9290.89660239],
#         [9202.41545055],
#         [9369.62808116],
#         [9326.59962378],
#         [9335.75240233]]),
#  array([[57107.12067189],
#         [58788.20967893],
#         [58102.19142623],
#         [55715.54665129],
#         [56573.5554719 ],
#         [52147.82118698],
#         [49764.1320816 ],
#         [50032.69313676],
#         [47885.62525472],
#         [45604.61575361]]))

# %%
import csv
from datetime import datetime

time=[]
prices=[]
with open("/content/BTC_USD_2013-10-01_2021-05-18-CoinDesk.csv","r") as g:
  csv=csv.reader(g,delimiter=",")
  next(csv)
  for line in csv :
    time.append(datetime.strptime(line[1],"%Y-%m-%d"))
    prices.append(float(line[2]))

time[:10] , prices[:10]
# Out:
# ([datetime.datetime(2013, 10, 1, 0, 0),
#   datetime.datetime(2013, 10, 2, 0, 0),
#   datetime.datetime(2013, 10, 3, 0, 0),
#   datetime.datetime(2013, 10, 4, 0, 0),
#   datetime.datetime(2013, 10, 5, 0, 0),
#   datetime.datetime(2013, 10, 6, 0, 0),
#   datetime.datetime(2013, 10, 7, 0, 0),
#   datetime.datetime(2013, 10, 8, 0, 0),
#   datetime.datetime(2013, 10, 9, 0, 0),
#   datetime.datetime(2013, 10, 10, 0, 0)],
#  [123.65499,
#   125.455,
#   108.58483,
#   118.67466,
#   121.33866,
#   120.65533,
#   121.795,
#   123.033,
#   124.049,
#   125.96116])

# %%
df
# Out:
#      Currency        Date  Closing Price (USD)  24h Open (USD)  \
# 0         BTC  2013-10-01           123.654990      124.304660
# 1         BTC  2013-10-02           125.455000      123.654990
# 2         BTC  2013-10-03           108.584830      125.455000
# 3         BTC  2013-10-04           118.674660      108.584830
# 4         BTC  2013-10-05           121.338660      118.674660
# ...       ...         ...                  ...             ...
# 2782      BTC  2021-05-14         49764.132082    49596.778891
# 2783      BTC  2021-05-15         50032.693137    49717.354353
# 2784      BTC  2021-05-16         47885.625255    49926.035067
# 2785      BTC  2021-05-17         45604.615754    46805.537852
# 2786      BTC  2021-05-18         43144.471291    46439.336570
#
#       24h High (USD)  24h Low (USD)
# 0         124.751660     122.563490
# 1         125.758500     123.633830
# 2         125.665660      83.328330
# 3         118.675000     107.058160
# ...

# %%
plt.scatter(time,prices)

# %%
def mean_absolute_scaled_error(y_true, y_pred):

  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

# %%
def evaluation_metrics(true , predicted):
  true = tf.cast(true, dtype=tf.float32)
  predicted = tf.cast(predicted, dtype=tf.float32)


  mae = tf.keras.losses.MeanAbsoluteError(true , predicted  )
  mse = tf.keras.losses.MeanSquaredError(true , predicted , reduction="mean")
  rmse = tf.sqrt(mse)
  mape = tf.keras.losses.MeanAbsolutePercentageError(true , predicted , reduction="mean")
  mase = mean_absolute_scaled_error(true , predicted)

  return {"mae"    : mae.numpy(),
          "mse"    : mse.numpy(),
          "rmse"   : rmse.numpy(),
          "mape"   : mape.numpy(),
          "mase"   : mase.numpy()}

# %%
model_0_pred=naive_forecast

# %%
naive_results=evaluate_preds( y_test[1:], naive_forecast)
naive_results
# Out:
# {'mae': 567.9802,
#  'mse': 1147547.0,
#  'rmse': 1071.2362,
#  'mape': 2.5165246,
#  'mase': 0.99957}

# %%
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.MeanAbsoluteError()(y_true,( y_pred))
  mse = tf.keras.metrics.MeanSquaredError()(y_true, (y_pred)) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.MeanAbsolutePercentageError()(y_true,( y_pred))
  mase = mean_absolute_scaled_error(y_true,( y_pred))


  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy()}

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Create function to view NumPy arrays as windows
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
x_train , x_test
# Out:
# (               0
#  0     2013-10-01
#  1     2013-10-02
#  2     2013-10-03
#  3     2013-10-04
#  4     2013-10-05
#  ...          ...
#  2224  2019-11-03
#  2225  2019-11-04
#  2226  2019-11-05
#  2227  2019-11-06
#  2228  2019-11-07
#
#  [2229 rows x 1 columns],
#  array([[ 123.65499   ],
#         [ 125.455     ],
#         [ 108.58483   ],
#         ...,
#         [9369.62808116],
#         [9326.59962378],
#         [9335.75240233]]))

# %%
import os
file="model_checkpoints"
os.path.join("model_checkpoints","model_1.ckpt")
# Out:
# 'model_checkpoints/model_1.ckpt'

# %% [markdown]
# # MODEL_1 -> USING ANN (HORIZON-1 , WINDOW_SIZE-7)

# %%
horizon = 1
window_size = 7

# %% [markdown]
# first the big dataset is converted to required columns dataset like date and prices and date is seperate and the prices are seperate in numpy format

# %%
import numpy as np

# %%
full_windows , full_labels = make_windows(price , window_size=7 , horizon=1)

# %%
def make_splits(full_windows,full_labels,size=0.2):

  length=int((1-size) * len(full_windows))
  train_windows = full_windows[:length]
  train_labels = full_labels[:length]
  test_windows = full_windows[length:]
  test_labels = full_labels[length:]

  return train_windows , train_labels , test_windows , test_labels

# %%
train_windows , train_labels , test_windows , test_labels = make_splits(full_windows = full_windows , full_labels = full_labels)

# %%
tf.random.set_seed(28)

model_1=tf.keras.Sequential([
    tf.keras.layers.Dense(128,activation="relu"), #batch size is 128.So,128 neurons
    tf.keras.layers.Dense(1)
],name="model_1_ANN")

model_1.compile(loss="mae",optimizer=tf.keras.optimizers.Adam(),metrics=["mae"])

model_1.fit(train_windows , train_labels , epochs=100 , validation_data=(test_windows , test_labels))
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2725.7917 - mae: 2725.7917 - val_loss: 4202.1040 - val_mae: 4202.1045
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 355.4106 - mae: 355.4106 - val_loss: 1216.8372 - val_mae: 1216.8372
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 211.9879 - mae: 211.9879 - val_loss: 1234.1274 - val_mae: 1234.1274
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 211.9862 - mae: 211.9862 - val_loss: 1227.7515 - val_mae: 1227.7516
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 211.7875 - mae: 211.7875 - val_loss: 1219.4192 - val_mae: 1219.4193
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 211.6811 - mae: 211.6811 - val_loss: 1213.3000 - val_mae: 1213.2999
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 211.7263 - mae: 211.7263 - val_loss: 1210.4456 - val_mae: 1210.4456
# Epoch 8/100
# ...

# %%
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), # create filepath to save model
                                            verbose=0, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %%
model_1.evaluate(test_windows ,  test_labels)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 589.0803 - mae: 589.0803
# [1197.1832275390625, 1197.1832275390625]

# %%
model_1_preds=model_1.predict(test_windows)
model_1_preds[:5]
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[[9323.853],
#         [9235.082],
#         [9402.841],
#         [9359.671],
#         [9368.854],
#         [9259.231],
#         [8825.694]],
#
#        [[9235.082],
#         [9402.841],
#         [9359.671],
#         [9368.854],
#         [9259.231],
#         [8825.694],
#         [8829.39 ]],
#
#        [[9402.841],
#         [9359.671],
#         [9368.854],
#         [9259.231],
#         [8825.694],
#         [8829.39 ],
#         [9113.458]],
#
#        [[9359.671],
#         [9368.854],
#         [9259.231],
#         [8825.694],
#         [8829.39 ],
#         [9113.458],
#         [8742.601]],
#
#        [[9368.854],
#         [9259.231],
#         [8825.694],
#         [8829.39 ],
#         [9113.458],
#         [8742.601],
#         [8792.12 ]]], dtype=float32)

# %%
model_1_results = evaluate_preds(test_labels , model_1_preds)
model_1_results
# Out:
# {'mae': 1197.1832,
#  'mse': 5017047.5,
#  'rmse': 2239.8767,
#  'mape': 5.2910595,
#  'mase': 2.1031194}

# %%
import tensorflow as tf
import os

# ... (rest of your code)

def evaluate_preds(y_true, y_pred):
  # ... (other parts of your function)

  # Calculate various metrics
  mae = tf.keras.losses.mean_absolute_error(y_true, tf.squeeze(y_pred)) # Use tf.keras.losses.mean_absolute_error
  mse = tf.keras.losses.mean_squared_error(y_true, tf.squeeze(y_pred)) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)

  # ... (rest of your function)

# %% [markdown]
# # MODEL_2 -> USING ANN WINDOW_SIZE=30 , HORIZON = 1

# %%
full_windows , full_labels = make_windows(price , window_size=30 , horizon = 1)

# %%
train_windows , train_labels , test_windows , test_labels = make_splits(full_windows=full_windows , full_labels=full_labels)

# %%
tf.random.set_seed(28)

model_2=tf.keras.Sequential([
    tf.keras.layers.Dense(128,activation="relu"), #batch size is 128.So,128 neurons
    tf.keras.layers.Dense(1)
],name="model_2_ANN")

model_2.compile(loss="mae",optimizer=tf.keras.optimizers.Adam(),metrics=["mae"])

model_2.fit(train_windows , train_labels , epochs=100 , validation_data=(test_windows , test_labels)
)
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 28s 13ms/step - loss: 2828.8872 - mae: 2828.8870 - val_loss: 2991.1396 - val_mae: 2991.1396
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 471.3022 - mae: 471.3022 - val_loss: 2405.0447 - val_mae: 2405.0449
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 466.1852 - mae: 466.1852 - val_loss: 2403.6118 - val_mae: 2403.6118
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 466.4143 - mae: 466.4143 - val_loss: 2399.1069 - val_mae: 2399.1067
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 466.5441 - mae: 466.5441 - val_loss: 2400.2891 - val_mae: 2400.2891
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 466.4839 - mae: 466.4839 - val_loss: 2400.3979 - val_mae: 2400.3979
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 466.4610 - mae: 466.4609 - val_loss: 2402.4373 - val_mae: 2402.4373
# Epoch 8/100
# ...

# %%
model_2.evaluate(test_windows , test_labels)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1299.8423 - mae: 1299.8423
# [2395.789794921875, 2395.789794921875]

# %%
model_2_preds=model_2.predict(test_windows)
model_2_preds[:5]
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[[8342.612 ],
#         [8167.3726],
#         [8008.879 ],
#         [8063.073 ],
#         [7975.3247],
#         [7948.454 ],
#         [8205.221 ],
#         [8205.148 ],
#         [8078.413 ],
#         [7425.9385],
#         [7466.1074],
#         [8595.815 ],
#         [9175.4375],
#         [9582.175 ],
#         [9462.126 ],
#         [9459.63  ],
#         [9230.083 ],
#         [9135.572 ],
#         [9201.743 ],
#         [9294.932 ],
#         [9206.521 ],
#         [9373.601 ],
#         [9330.606 ],
#         [9339.752 ],
#         [9230.572 ],
#         [8798.789 ],
#         [8802.47  ],
#         [9085.389 ],
#         [8716.03  ],
#         [8765.35  ]],
#
#        [[8167.3726],
#         [8008.879 ],
#         [8063.073 ],
#         [7975.3247],
#         [7948.454 ],
#         [8205.221 ],
#         [8205.148 ],
#         [8078.413 ],
#         [7425.9385],
#         [7466.1074],
#         [8595.815 ],
# ...

# %%
model_2_results=evaluate_preds(test_labels ,model_2_preds )
model_2_results
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-23e8682931bc> in <cell line: 1>()
# ----> 1 model_2_results=evaluate_preds(test_labels ,model_2_preds )
#       2 model_2_results
#
# <ipython-input-185-b420b834147e> in evaluate_preds(y_true, y_pred)
#       8
#       9   # Calculate various metrics
# ---> 10   mae = tf.keras.losses.mean_absolute_error(y_true, tf.squeeze(y_pred)) # Use tf.keras.losses.mean_absolute_error
#      11   mse = tf.keras.losses.mean_squared_error(y_true, tf.squeeze(y_pred)) # puts and emphasis on outliers (all errors get squared)
#      12   rmse = tf.sqrt(mse)
#
# AttributeError: module 'keras._tf_keras.keras.losses' has no attribute 'mean_absolute_error'

# %% [markdown]
# # MODEL_3 -> USING ANN  HORIZON-7 , WINDOW_SIZE-30

# %%
full_windows , full_labels = make_windows(price , window_size=30 , horizon =7)

# %%
price.shape

# %%
full_labels.shape

# %%
train_windows , train_labels , test_windows , test_labels = make_splits(full_windows = full_windows , full_labels = full_labels)

# %%
tf.random.set_seed(28)

model_3=tf.keras.Sequential([
    tf.keras.layers.Dense(128,activation="relu"), #batch size is 128.So,128 neurons
    tf.keras.layers.Dense(7),
    # tf.keras.layers.Reshape((7, 1)),

],name="model_3_ANN")

model_3.compile(loss="mae",optimizer=tf.keras.optimizers.Adam(),metrics=["mae"])

model_3.fit(train_windows , train_labels , epochs=100 , validation_data=(test_windows , test_labels))

# %%
model_3.evaluate(test_windows , test_labels)

# %%
model_3_preds=model_3.predict(test_windows)
model_3_preds[:5]

# %%
model_3_results = evaluate_preds(test_labels ,model_3_preds )
model_3_results

# %%
naive_results, model_2_results

# %% [markdown]
# # MODEL_4 -> USING CONV1D HORIZON=1 , WINDOW_SIZE=7

# %%
full_windows , full_labels = make_windows(price , window_size=7 , horizon = 1)

# %%
full_windows.shape

# %%
train_windows , train_labels , test_windows , test_labels = make_splits(full_windows=full_windows , full_labels=full_labels)

# %% [markdown]
# it takes in the format (batch_size,timesteps,inputdims)
# here we are only passing (batch_size,timesteps)
# we need to do it like [[1],[2],[3]...[7]] from [1,2,3....7]

# %%
tf.random.set_seed(28)




# Create model
model_4 = tf.keras.Sequential([
  # Create Lambda layer to reshape inputs, without this layer, the model will produce error
  # layers.Lambda(lambda x: tf.expand_dims(x, axis=1)), # resize the inputs to adjust for window size / Conv1D and input requirements
  # tf.keras.layers.Lambda(lambda x:tf.expand_dims(x,axis=1)),
  tf.keras.layers.Conv1D(filters=128, kernel_size=7, padding="causal", activation="relu"),
  tf.keras.layers.Dense(1)
], name="model_4_conv1D")

# Compile model
model_4.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Fit model
model_4.fit(train_windows , train_labels , epochs=100 , validation_data=(test_windows , test_labels))

# %%
model_4.evaluate(test_windows , test_labels)

# %%
model_4_preds=model_4.predict(test_windows)
model_4_preds[:5]

# %%
model_4_results=evaluate_preds(test_labels,model_4_preds)
model_4_results

# %%
naive_results, model_2_results , model_3_results , model_4_results

# %% [markdown]
# # MODEL_5 -> USING LSTM HORIZON-1 , WINDOW_SIZE-7

# %%
tf.random.set_seed(28)




# Create model
model_5 = tf.keras.Sequential([
  # Create Lambda layer to reshape inputs, without this layer, the model will produce error


  # tf.keras.layers.Lambda(lambda y:tf.expand_dims(y,axis=1)),
  tf.keras.layers.LSTM(128, activation="relu"),
  tf.keras.layers.Dense(1)
], name="model_5_LSTM")

# Compile model
model_5.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam())

# Fit model
model_5.fit(train_windows , train_labels , epochs=100 , validation_data=(test_windows , test_labels))

# %%
model_5.evaluate(test_windows , test_labels)

# %%
model_5_preds=model_5.predict(test_windows)
model_5_preds[:5]

# %%
model_5_results=evaluate_preds(test_labels , model_5_preds)
model_5_results

# %%
naive_results,model_1_results, model_2_results , model_3_results , model_4_results

# %%
import matplotlib.pyplot as plt

# Defining the data
models = ["Model 1", "Model 2", "Model 3", "Model 4", "Model 5"]
metrics = ["MAE", "MSE", "RMSE", "MAPE", "MASE"]
data = [
    [567.9802, 1147547.0, 1071.2362, 2.5165246, 0.99957],
    [1195.7882, 5012305.0, 2238.8176, 5.288994, 2.100669],
    [2407.069, 18120604.0, 4256.83, 11.402285, 4.2075806],
    [1196.012, 5013009.5, 2238.975, 5.2892985, 2.1010616],
    [1228.173, 5153808.5, 2270.2, 5.454123, 2.1575599],
]

# Plotting Accuracy (MAPE)
plt.figure(figsize=(10, 6))
plt.plot(models, [metric[3] for metric in data], marker='o', label='MAPE')
plt.title('Model Accuracy (MAPE)')
plt.xlabel('Models')
plt.ylabel('MAPE')
plt.legend()
plt.grid(True)
plt.show()

# Plotting Other Metrics (MAE, MSE, RMSE, MASE)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# MAE
axes[0, 0].plot(models, [metric[0] for metric in data], marker='o', label='MAE')
axes[0, 0].set_title('Mean Absolute Error (MAE)')
axes[0, 0].legend()
axes[0, 0].grid(True)

# MSE
axes[0, 1].plot(models, [metric[1] for metric in data], marker='o', label='MSE')
axes[0, 1].set_title('Mean Squared Error (MSE)')
axes[0, 1].legend()
axes  [0, 1].grid(True)

# RMSE
axes[1, 0].plot(models, [metric[2] for metric in data], marker='o', label='RMSE')
axes[1, 0].set_title('Root Mean Squared Error (RMSE)')
axes[1, 0].legend()
axes[1, 0].grid(True)

# MASE
axes[1, 1].plot(models, [metric[4] for metric in data], marker='o', label='MASE')
axes[1, 1].set_title('Mean Absolute Scaled Error (MASE)')
axes[1, 1].legend()
axes[1, 1].grid(True)

fig.suptitle('Model Performance Metrics')
plt.tight_layout()
plt.show()
